# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('D:/aiml/Cars93.csv')
df
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0         25           31                None  ...          5    177
# 1         18           25  Driver & Passenger  ...          5    195
# 2         20           26         Driver only  ...          5    180
# 3         19           26  Driver & Passenger  ...          6    193
# 4         22           30         Driver only  ...          4    186
# ..       ...          ...                 ...  ...        ...    ...
# 88        17           21                None  ...          7    187
# 89        21           30                None  ...          5    180
# 90        18           25                None  ...          4    159
# 91        21           28         Driver only  ...          5    190
# 92        20           28  Driver & Passenger  ...          5    184
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# 0         102     68           37            26.5         11.0    2705
# 1         115     71           38            30.0         15.0    3560
# 2         102     67           37            28.0         14.0    3375
# 3         106     70           37            31.0         17.0    3405
# 4         109     69           39            27.0         13.0    3640
# ..        ...    ...          ...             ...          ...     ...
# 88        115     72           38            34.0          NaN    3960
# 89        103     67           35            31.5         14.0    2985
# 90         97     66           36            26.0         15.0    2810
# 91        104     67           37            29.5         14.0    2985
# 92        105     69           38            30.0         15.0    3245
#
#      Origin                Make
# 0   non-USA       Acura Integra
# 1   non-USA        Acura Legend
# 2   non-USA             Audi 90
# 3   non-USA            Audi 100
# 4   non-USA            BMW 535i
# ..      ...                 ...
# 88  non-USA  Volkswagen Eurovan
# 89  non-USA   Volkswagen Passat
# 90  non-USA  Volkswagen Corrado
# 91  non-USA           Volvo 240
# 92  non-USA           Volvo 850
#
# [93 rows x 28 columns]

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.hist(df['MPG.city'])
ax.set_title('histogram to check frequency of mpg')
ax.set_ylabel('miles per gallon',fontsize='12')
ax.set_xlabel("frequency",fontsize='12')
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5100\3680697186.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title('to determine whether a car with high horsepower gives lower.mileage')
ax.set_ylabel('Horsepower',fontsize='12')
ax.set_xlabel("MPG",fontsize='12')
ax.scatter(df['Horsepower'],df['MPG.city'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5100\3048566624.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title('price range of all different cars')
ax.set_ylabel('Horsepower',fontsize='12')
ax.set_xlabel("MPG",fontsize='12')
ax.boxplot(df['Price'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5100\2918405855.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df=df.groupby(by=['Horsepower'])
line_df=line_df.mean()
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
plt.plot(df['Horsepower'],df['EngineSize'],label='EngineSize')
ax.set_title('variation in EngineSize')
ax.set_ylabel('EngineSize')
ax.set_xlabel('Horsepower')
ax.legend()
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5100\438524262.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
