# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_excel("D:/aiml/Book1.xlsx")
df
# Out:
#    defaulter student    balance    income
# 0         No     Yes   817.1804  12106.14
# 1        Yes     Yes  1486.9980  17854.40
# 2        Yes     Yes  1102.4350  17391.78
# 3        Yes     Yes  1233.4460       NaN
# 4        Yes     NaN  1276.6850  19282.44
# 5        Yes     Yes  1289.2460  13624.55
# 6         No     Yes   673.8124  17672.29
# 7         No      No   870.4124  17685.45
# 8         No     NaN   903.1768       NaN
# 9         No     Yes   879.6270  14898.31
# 10   unknown     Yes  1000.0000  16900.00

# %%
df.income=df.income.fillna(0)
df
# Out:
#    defaulter student    balance    income
# 0         No     Yes   817.1804  12106.14
# 1        Yes     Yes  1486.9980  17854.40
# 2        Yes     Yes  1102.4350  17391.78
# 3        Yes     Yes  1233.4460      0.00
# 4        Yes     NaN  1276.6850  19282.44
# 5        Yes     Yes  1289.2460  13624.55
# 6         No     Yes   673.8124  17672.29
# 7         No      No   870.4124  17685.45
# 8         No     NaN   903.1768      0.00
# 9         No     Yes   879.6270  14898.31
# 10   unknown     Yes  1000.0000  16900.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   defaulter  11 non-null     object
#  1   student    9 non-null      object
#  2   balance    11 non-null     float64
#  3   income     11 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 480.0+ bytes

# %%
plt.boxplot(df['balance'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d4c4af4b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d4c4b04100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d4c4af4850>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d4c4b046a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d4c4b04970>],
#  'means': []}

# %%
for i in df['balance']:
    Q1=df['balance'].quantile(0.25)
    Q3=df['balance'].quantile(0.75)
    IQR=Q3-Q1
    lower_tail=Q1-1.5*IQR
    upper_tail=Q3+1.5*IQR
    if i>upper_tail or i<lower_tail:
     df['balance']=df['balance'].drop(i)
plt.boxplot(df['balance'])
plt.show()

# %%
df.isnull()
# Out:
#     defaulter  student  balance  income
# 0       False    False    False   False
# 1       False    False    False   False
# 2       False    False    False   False
# 3       False    False    False   False
# 4       False     True    False   False
# 5       False    False    False   False
# 6       False    False    False   False
# 7       False    False    False   False
# 8       False     True    False   False
# 9       False    False    False   False
# 10      False    False    False   False

# %%
df.dropna()
# Out:
#    defaulter student    balance    income
# 0         No     Yes   817.1804  12106.14
# 1        Yes     Yes  1486.9980  17854.40
# 2        Yes     Yes  1102.4350  17391.78
# 5        Yes     Yes  1289.2460  13624.55
# 6         No     Yes   673.8124  17672.29
# 7         No      No   870.4124  17685.45
# 9         No     Yes   879.6270  14898.31
# 10   unknown     Yes  1000.0000  16900.00

# %%
df.fillna(0)
# Out:
#    defaulter student    balance        income
# 0         No     Yes   817.1804  12106.140000
# 1        Yes     Yes  1486.9980  17854.400000
# 2        Yes     Yes  1102.4350  17391.780000
# 3        Yes     Yes  1233.4460  16379.484444
# 4        Yes       0  1276.6850  19282.440000
# 5        Yes     Yes  1289.2460  13624.550000
# 6         No     Yes   673.8124  17672.290000
# 7         No      No   870.4124  17685.450000
# 8         No       0   903.1768  16379.484444
# 9         No     Yes   879.6270  14898.310000
# 10   unknown     Yes  1000.0000  16900.000000

# %%
df.fillna(df.mean())
df['income'].fillna(df['income'].mean(),inplace=True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_852\2923480557.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#    defaulter student    balance        income
# 0         No     Yes   817.1804  12106.140000
# 1        Yes     Yes  1486.9980  17854.400000
# 2        Yes     Yes  1102.4350  17391.780000
# 3        Yes     Yes  1233.4460  16379.484444
# 4        Yes     NaN  1276.6850  19282.440000
# 5        Yes     Yes  1289.2460  13624.550000
# 6         No     Yes   673.8124  17672.290000
# 7         No      No   870.4124  17685.450000
# 8         No     NaN   903.1768  16379.484444
# 9         No     Yes   879.6270  14898.310000
# 10   unknown     Yes  1000.0000  16900.000000

# %%
df.fillna(df.mode())
df['balance'].fillna(df['balance'].mode(),inplace=True)
df
# Out:
#    defaulter student    balance        income
# 0         No     Yes   817.1804  12106.140000
# 1        Yes     Yes  1486.9980  17854.400000
# 2        Yes     Yes  1102.4350  17391.780000
# 3        Yes     Yes  1233.4460  16379.484444
# 4        Yes     NaN  1276.6850  19282.440000
# 5        Yes     Yes  1289.2460  13624.550000
# 6         No     Yes   673.8124  17672.290000
# 7         No      No   870.4124  17685.450000
# 8         No     NaN   903.1768  16379.484444
# 9         No     Yes   879.6270  14898.310000
# 10   unknown     Yes  1000.0000  16900.000000

# %%
df.fillna(df.mean())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_852\634187881.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#    defaulter student    balance        income
# 0         No     Yes   817.1804  12106.140000
# 1        Yes     Yes  1486.9980  17854.400000
# 2        Yes     Yes  1102.4350  17391.780000
# 3        Yes     Yes  1233.4460  16379.484444
# 4        Yes     NaN  1276.6850  19282.440000
# 5        Yes     Yes  1289.2460  13624.550000
# 6         No     Yes   673.8124  17672.290000
# 7         No      No   870.4124  17685.450000
# 8         No     NaN   903.1768  16379.484444
# 9         No     Yes   879.6270  14898.310000
# 10   unknown     Yes  1000.0000  16900.000000

# %%
df.fillna(0)
# Out:
#    defaulter student    balance        income
# 0         No     Yes   817.1804  12106.140000
# 1        Yes     Yes  1486.9980  17854.400000
# 2        Yes     Yes  1102.4350  17391.780000
# 3        Yes     Yes  1233.4460  16379.484444
# 4        Yes       0  1276.6850  19282.440000
# 5        Yes     Yes  1289.2460  13624.550000
# 6         No     Yes   673.8124  17672.290000
# 7         No      No   870.4124  17685.450000
# 8         No       0   903.1768  16379.484444
# 9         No     Yes   879.6270  14898.310000
# 10   unknown     Yes  1000.0000  16900.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
car=pd.read_excel('D:/aiml/car_data.xlsx')
car
# Out:
#     Unnamed: 0 Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura     Integra    Small       12.9   15.9       18.8
# 1            2        Acura      Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi          90  Compact       25.9   29.1       32.3
# 3            4         Audi         100  Midsize       30.8   37.7       44.6
# 4            5          BMW        535i  Midsize       23.7   30.0       36.2
# 5            6        Buick     Century  Midsize       14.2   15.7       17.3
# 6            7        Buick     LeSabre    Large       19.9   20.8       21.7
# 7            8        Buick  Roadmaster    Large       22.6   23.7       24.9
# 8            9        Buick     Riviera  Midsize       26.3   26.3       26.3
# 9           10     Cadillac     DeVille    Large       33.0   34.7       36.3
# 10          11     Cadillac     Seville  Midsize       37.5   40.1       42.7
# ...

# %%
car.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers  Length  \
# 0        25           31                None  ...          5     177
# 1        18           25  Driver & Passenger  ...          5     195
# 2        20           26         Driver only  ...          5     180
# 3        19           26  Driver & Passenger  ...          6     193
# 4        22           30         Driver only  ...          4     186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
plt.boxplot(car['Weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d4ca77cee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d4ca78a400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d4ca77ccd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d4ca78a9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d4ca78ac70>],
#  'means': []}

# %%
for i in car['Weight']:
    Q1=car['Weight'].quantile(0.25)
    Q3=car['Weight'].quantile(0.75)
    IQR=Q3-Q1
    lower_tail=Q1-1.5*IQR
    upper_tail=Q3+1.5*IQR
    if i>upper_tail or i<lower_tail:
     car['Weight']=car['Weight'].drop(i)
plt.boxplot(car['Weight'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
#       6     upper_tail=Q3+1.5*IQR
#       7     if i>upper_tail or i<lower_tail:
# ----> 8      car['Weight']=car['Weight'].drop(i)
#       9 plt.boxplot(car['Weight'])
#      10 plt.show()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
ax.set_title('Weight')
ax.set_ylabel('Price',fontsize='12')
ax.set_xlabel("Weight",fontsize='12')
ax.boxplot(car['Weight'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5544\1491747354.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
for i in car['Weight']:
    Q1=car['Weight'].quantile(0.25)
    Q3=car['Weight'].quantile(0.75)
    IQR=Q3-Q1
    lower_tail=Q1-1.5*IQR
    upper_tail=Q3+1.5*IQR
if i>upper_tail or i<lower_tail:
 car['Weight']=car['Weight'].drop(i)
plt.boxplot(car['Weight'])
plt.show()
