# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\admin\anaconda3\lib\site-packages (2.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\admin\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (61.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.28.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.12.6)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.42.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\admin\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\admin\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\admin\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('D:/aiml/breast cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df=df.drop(columns=['id'],axis=0)
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
df.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df2=df.drop(['diagnosis'],axis=1,inplace=False)

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['diagnosis'])
df['diagnosis'] = np.where(df['diagnosis']=='M', 1, 0)
Y = df['diagnosis']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
from sklearn.preprocessing import Normalizer
# Instantiate
norm = Normalizer()
# Fit
norm.fit(x_train)
# Transform both training and testing sets
X_train_norm = norm.transform(x_train)
X_test_norm = norm.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train_norm, y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy: ",model.score(X_test_norm, y_test) * 100)
# Out:
# Accuracy:  80.11695906432749

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,f1_score
model = DecisionTreeClassifier()
model.fit(X_train_norm, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ",model.score(X_test_norm, y_test) * 100)
# Out:
# Accuracy:  95.32163742690058

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,f1_score
model = RandomForestClassifier()
# training
model.fit(X_train_norm, y_train)
# testing
y_pred = model.predict(X_test_norm)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       110
#            1       0.94      0.97      0.95        61
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.97      0.96       171
# weighted avg       0.97      0.96      0.97       171

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

# %%
Model = Sequential()

# %%
Model.add(Dense(units= 16, activation = 'relu', input_dim=30))
# units indicates here the ooutput dimention of Dense laye
Model.add(Dense(units=8, activation='relu'))
Model.add(Dense(units=6, activation='relu'))
Model.add(Dense(units=1, activation='sigmoid'))

# %%
Model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
Model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 16)                496
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  dense_6 (Dense)             (None, 6)                 54
#
#  dense_7 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 693
# Trainable params: 693
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(Model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
history=Model.fit(X_train_norm, y_train,validation_split=0.2, batch_size=1, epochs=50)
# Out:
# Epoch 1/50
# 318/318 [==============================] - 1s 2ms/step - loss: 0.6640 - accuracy: 0.6101 - val_loss: 0.6303 - val_accuracy: 0.6625
# Epoch 2/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.6472 - accuracy: 0.6101 - val_loss: 0.6158 - val_accuracy: 0.6625
# Epoch 3/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.6194 - accuracy: 0.6101 - val_loss: 0.5908 - val_accuracy: 0.6750
# Epoch 4/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.5789 - accuracy: 0.6730 - val_loss: 0.5436 - val_accuracy: 0.7000
# Epoch 5/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.5233 - accuracy: 0.7579 - val_loss: 0.4912 - val_accuracy: 0.7500
# Epoch 6/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.4605 - accuracy: 0.8239 - val_loss: 0.4345 - val_accuracy: 0.8250
# Epoch 7/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.3941 - accuracy: 0.8616 - val_loss: 0.3814 - val_accuracy: 0.8750
# Epoch 8/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8679 - val_loss: 0.3757 - val_accuracy: 0.8875
# Epoch 9/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.3059 - accuracy: 0.8994 - val_loss: 0.3076 - val_accuracy: 0.8750
# Epoch 10/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2828 - accuracy: 0.8962 - val_loss: 0.3018 - val_accuracy: 0.8875
# Epoch 11/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.9057 - val_loss: 0.3127 - val_accuracy: 0.9125
# Epoch 12/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2549 - accuracy: 0.8994 - val_loss: 0.2683 - val_accuracy: 0.8750
# Epoch 13/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2518 - accuracy: 0.8994 - val_loss: 0.2461 - val_accuracy: 0.8625
# Epoch 14/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.9088 - val_loss: 0.3128 - val_accuracy: 0.9000
# Epoch 15/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2350 - accuracy: 0.9151 - val_loss: 0.3230 - val_accuracy: 0.8875
# Epoch 16/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2423 - accuracy: 0.8994 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 17/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2300 - accuracy: 0.9057 - val_loss: 0.2956 - val_accuracy: 0.8750
# Epoch 18/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2352 - accuracy: 0.9057 - val_loss: 0.2260 - val_accuracy: 0.8625
# Epoch 19/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2436 - accuracy: 0.9119 - val_loss: 0.2748 - val_accuracy: 0.9125
# Epoch 20/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2371 - accuracy: 0.9057 - val_loss: 0.2275 - val_accuracy: 0.8875
# Epoch 21/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2358 - accuracy: 0.9277 - val_loss: 0.2220 - val_accuracy: 0.8750
# Epoch 22/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.9025 - val_loss: 0.2232 - val_accuracy: 0.8875
# Epoch 23/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2376 - accuracy: 0.8994 - val_loss: 0.2344 - val_accuracy: 0.8625
# Epoch 24/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2271 - accuracy: 0.9088 - val_loss: 0.3763 - val_accuracy: 0.8375
# Epoch 25/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2338 - accuracy: 0.9057 - val_loss: 0.2462 - val_accuracy: 0.9000
# Epoch 26/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.9088 - val_loss: 0.2223 - val_accuracy: 0.8875
# Epoch 27/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2460 - accuracy: 0.9088 - val_loss: 0.2194 - val_accuracy: 0.8875
# Epoch 28/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2398 - accuracy: 0.9057 - val_loss: 0.2423 - val_accuracy: 0.9000
# Epoch 29/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2355 - accuracy: 0.9151 - val_loss: 0.5523 - val_accuracy: 0.7625
# Epoch 30/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2479 - accuracy: 0.9057 - val_loss: 0.2882 - val_accuracy: 0.9000
# Epoch 31/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.9057 - val_loss: 0.3328 - val_accuracy: 0.8875
# Epoch 32/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.9151 - val_loss: 0.3218 - val_accuracy: 0.8875
# Epoch 33/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2346 - accuracy: 0.8994 - val_loss: 0.3052 - val_accuracy: 0.8875
# Epoch 34/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2527 - accuracy: 0.9151 - val_loss: 0.2721 - val_accuracy: 0.9125
# Epoch 35/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2439 - accuracy: 0.9057 - val_loss: 0.3476 - val_accuracy: 0.8875
# Epoch 36/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2438 - accuracy: 0.9025 - val_loss: 0.2366 - val_accuracy: 0.9125
# Epoch 37/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2360 - accuracy: 0.9025 - val_loss: 0.3368 - val_accuracy: 0.8875
# Epoch 38/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2367 - accuracy: 0.9025 - val_loss: 0.2569 - val_accuracy: 0.9000
# Epoch 39/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 0.9119 - val_loss: 0.2261 - val_accuracy: 0.9000
# Epoch 40/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2429 - accuracy: 0.9088 - val_loss: 0.2738 - val_accuracy: 0.9125
# Epoch 41/50
# 318/318 [==============================] - 0s 954us/step - loss: 0.2433 - accuracy: 0.9088 - val_loss: 0.2227 - val_accuracy: 0.8625
# Epoch 42/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2381 - accuracy: 0.9025 - val_loss: 0.2303 - val_accuracy: 0.8625
# Epoch 43/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2360 - accuracy: 0.8994 - val_loss: 0.2382 - val_accuracy: 0.9125
# Epoch 44/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2405 - accuracy: 0.8994 - val_loss: 0.3667 - val_accuracy: 0.8750
# Epoch 45/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9088 - val_loss: 0.3191 - val_accuracy: 0.8875
# Epoch 46/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2303 - accuracy: 0.9119 - val_loss: 0.3023 - val_accuracy: 0.8750
# Epoch 47/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2492 - accuracy: 0.9088 - val_loss: 0.5556 - val_accuracy: 0.7625
# Epoch 48/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.8962 - val_loss: 0.2382 - val_accuracy: 0.8625
# Epoch 49/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2425 - accuracy: 0.8994 - val_loss: 0.3910 - val_accuracy: 0.8500
# Epoch 50/50
# 318/318 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.9025 - val_loss: 0.2208 - val_accuracy: 0.8875

# %%
prediction = Model.predict(X_test_norm[1:])
# Out:
# 6/6 [==============================] - 0s 1ms/step

# %%
prediction
# Out:
# array([[6.4389311e-02],
#        [4.6740443e-04],
#        [3.6867198e-02],
#        [1.7296238e-01],
#        [5.2350797e-02],
#        [2.2705286e-05],
#        [9.9536085e-01],
#        [9.9587375e-01],
#        [9.0873772e-01],
#        [9.9893874e-01],
#        [5.0264144e-01],
#        [9.8634499e-01],
#        [5.1075250e-01],
#        [9.9103886e-01],
#        [9.9664432e-01],
#        [2.7096568e-04],
#        [6.0786441e-04],
#        [8.8619569e-04],
#        [6.9597061e-04],
#        [7.0491500e-05],
#        [6.1510509e-04],
#        [6.2286407e-03],
#        [9.6134663e-01],
#        [9.6083844e-01],
#        [6.6917092e-01],
#        [6.9945222e-03],
#        [9.9450767e-01],
#        [9.9428988e-01],
#        [1.1158550e-01],
#        [2.5991694e-04],
#        [4.4838465e-03],
#        [4.1558953e-05],
#        [4.3892013e-03],
#        [1.3484258e-03],
#        [2.6673425e-03],
#        [9.9452138e-01],
#        [1.7106086e-03],
#        [9.6949385e-03],
#        [6.9644190e-02],
#        [9.9154085e-01],
#        [6.9386399e-01],
#        [5.2368149e-02],
#        [1.2366341e-03],
#        [1.2126149e-02],
#        [2.4121164e-04],
#        [5.6518300e-04],
#        [8.1425118e-01],
#        [2.3971198e-03],
#        [1.2984376e-04],
#        [2.3199147e-01],
#        [1.2376704e-01],
#        [2.7761381e-04],
#        [3.8678199e-03],
#        [1.5497995e-02],
#        [9.9493212e-01],
#        [1.2145051e-03],
#        [9.9927390e-01],
#        [9.8985100e-01],
#        [1.4059222e-01],
#        [7.1962371e-05],
#        [4.4819012e-02],
#        [9.9369782e-01],
#        [7.3461357e-05],
#        [6.3031159e-02],
#        [2.3141693e-02],
#        [2.0636436e-02],
#        [1.0009175e-01],
#        [3.7824668e-04],
#        [1.1340631e-03],
#        [2.7142954e-04],
#        [4.8385152e-01],
#        [8.1591932e-03],
#        [8.8414563e-05],
#        [9.9315244e-01],
#        [9.9930519e-01],
#        [8.4760666e-02],
#        [5.8804852e-01],
#        [1.2024439e-01],
#        [5.5927220e-03],
#        [9.3561655e-01],
#        [6.3462633e-01],
#        [6.2420673e-04],
#        [1.2377181e-04],
#        [1.3126946e-02],
#        [9.1798508e-01],
#        [9.9562323e-01],
#        [1.1022694e-01],
#        [4.2240057e-04],
#        [9.1955317e-03],
#        [5.0968281e-04],
#        [8.0629063e-01],
#        [2.3720437e-01],
#        [3.3356456e-04],
#        [4.5648256e-01],
#        [2.6005945e-01],
#        [2.1895429e-03],
#        [4.1386101e-04],
#        [9.9542004e-01],
#        [9.9567062e-01],
#        [3.8727534e-01],
#        [6.9022458e-03],
#        [5.3010415e-04],
#        [1.9465393e-03],
#        [4.7444616e-02],
#        [4.3375450e-04],
#        [1.3483932e-03],
#        [7.0430212e-02],
#        [4.8285056e-02],
#        [9.9756187e-01],
#        [9.9566615e-01],
#        [7.4196816e-04],
#        [9.9849486e-01],
#        [9.9764299e-01],
#        [2.8798252e-04],
#        [5.9209261e-03],
#        [9.9044442e-01],
#        [9.8905557e-01],
#        [3.8590818e-04],
#        [3.6461984e-03],
#        [9.9484318e-01],
#        [9.9306715e-01],
#        [9.9974418e-01],
#        [9.9498761e-01],
#        [9.9069655e-01],
#        [2.2178094e-01],
#        [1.9177282e-01],
#        [9.9263352e-01],
#        [3.9200738e-02],
#        [9.0470994e-03],
#        [9.9371535e-01],
#        [1.3466552e-02],
#        [9.9847382e-01],
#        [3.5074923e-02],
#        [8.8200613e-04],
#        [1.2962881e-01],
#        [4.3773759e-02],
#        [1.0747760e-04],
#        [1.5374378e-04],
#        [5.3610047e-03],
#        [9.9587387e-01],
#        [8.5813785e-01],
#        [9.9226952e-01],
#        [1.0881850e-03],
#        [1.0286268e-02],
#        [4.5913435e-03],
#        [3.3534047e-01],
#        [9.7498119e-01],
#        [2.5522025e-04],
#        [4.6397567e-01],
#        [9.4319355e-01],
#        [4.0060044e-03],
#        [8.0720166e-04],
#        [6.7587565e-03],
#        [1.7585333e-03],
#        [4.0276069e-03],
#        [1.4877661e-01],
#        [9.9667633e-01],
#        [9.9616474e-01],
#        [1.4165186e-02],
#        [5.3874105e-03],
#        [9.9972665e-01],
#        [7.5041562e-01],
#        [1.8787490e-02],
#        [4.2749434e-03],
#        [3.1239329e-02],
#        [1.8101335e-03],
#        [9.9065447e-01],
#        [9.9532866e-01],
#        [9.6732390e-01],
#        [3.6936324e-02]], dtype=float32)
