# %%
import pandas as pd
df = pd.read_csv('D:/aiml/autompg.csv.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.scatter(df['horsepower'],df['mpg'])
ax.set_title("Scatter plot of horsepower and mileage",fontsize=16)
ax.set_ylabel('Mileage per gallon',fontsize=12)
ax.set_xlabel('Horsepower',fontsize=12)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\86178204.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.hist(df['horsepower'], bins=20)
ax.set_title('Distribution of Horsepower',fontsize = 17)
ax.set_ylabel('Frequency',fontsize=12)
ax.set_xlabel('Horsepower',fontsize=12)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\2279070076.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df=df.groupby(by=['model_year'])
line_df = line_df.mean() 
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(line_df['mpg']/10,label='Mileage /10')
ax.plot(line_df['weight']/1000,label='Weight /1000')
ax.plot(line_df['horsepower']/100,label='Horsepower /100')
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\3293606369.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('Distribution of mileage')
ax.boxplot(df['mpg'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\2270270206.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import pandas as pd
df1=pd.read_csv('D:/aiml/mtcars.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.scatter(df1['wt'],df1['mpg'])
ax.set_title("Scatter plot of mpg and model",fontsize=16)
ax.set_ylabel('price',fontsize=12)
ax.set_xlabel('mpg',fontsize=12)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\1085327240.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.hist(df1['mpg'], bins=20)
ax.set_title('Distribution of mpg',fontsize = 17)
ax.set_ylabel('Frequency',fontsize=12)
ax.set_xlabel('mpg',fontsize=12)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\2507333431.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df1=df1.groupby(by=['drat'])
line_df1 = line_df.mean() 
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(line_df1['mpg']/10,label='price/10')
ax.plot(line_df1['hp']/1000,label='hp/1000')
ax.plot(line_df1['wt']/100,label=' /100')
ax.set_title('price vs hp vs wt',fontsize = 17)
ax.set_ylabel('wt',fontsize=12)
ax.set_xlabel('drat',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\4130371371.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('Distribution of Model')
ax.boxplot(df['mpg'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\625702134.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
cars_df = pd.read_csv("D:/aiml/Data_Cars93.csv")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
cars_df = pd.read_csv("D:/aiml/Data_Cars93.csv")
columns = ["Manufacturer","Model","Type","Price","MPG.city","MPG.highway","Horsepower","Rear.seat.room","Passengers"]
cars_df[columns].head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city  MPG.highway  Horsepower  \
# 0        Acura  Integra    Small   15.9        25           31         140
# 1        Acura   Legend  Midsize   33.9        18           25         200
# 2         Audi       90  Compact   29.1        20           26         172
# 3         Audi      100  Midsize   37.7        19           26         172
# 4          BMW     535i  Midsize   30.0        22           30         208
#
#    Rear.seat.room  Passengers
# 0            26.5           5
# 1            30.0           5
# 2            28.0           5
# 3            31.0           6
# 4            27.0           4

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[6,6])
ax = fig.add_axes([0, 0, 1, 1])
ax.scatter(cars_df['Horsepower'],cars_df['Manufacturer'])
ax.set_title("Scatter plot of Audi and BMW",fontsize=16)
ax.set_ylabel('Model',fontsize=16)
ax.set_xlabel('Price',fontsize=16)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\3621921711.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[3,3])
ax = fig.add_axes([0, 0, 1, 1])
ax.hist(cars_df['Type'], bins=20)
ax.set_title('Distribution of Type',fontsize = 17)
ax.set_ylabel('Frequency',fontsize=12)
ax.set_xlabel('Model',fontsize=12)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_436\4152580003.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
